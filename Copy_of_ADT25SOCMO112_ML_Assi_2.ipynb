# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav5857/Machine-Learning/blob/main/Copy_of_ADT25SOCMO112_ML_Assi_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1:- Import Libraries

# %% [markdown]
# # Assignment-2: Basic Data Pre-Processing (UCI Dataset)
# # Objective: Perform core data-preprocessing operations on a real dataset using Python.
# # Dataset used: Student Dataset - Github

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# Step 2:- Load Dataset

# %%
df = pd.read_csv('/content/student-data.csv')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences passed
# 0       no       no       4         3      4    1    1      3        6     no
# 1      yes       no       5         3      3    1    1      3        4     no
# 2      yes       no       4         3      2    2    3      3       10    yes
# 3      yes      yes       3         2      2    1    1      5        2    yes
#
# [4 rows x 31 columns]
# ...
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# ![Screenshot 2026-01-18 135101.png](data:image/png;base64,...)

# %%
print(df.shape)
df.info()
# Out:
# (4, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      4 non-null      object
#  1   sex         4 non-null      object
#  2   age         4 non-null      int64
#  3   address     4 non-null      object
#  4   famsize     4 non-null      object
#  5   Pstatus     4 non-null      object
#  6   Medu        4 non-null      int64
#  7   Fedu        4 non-null      int64
#  8   Mjob        4 non-null      object
#  9   Fjob        4 non-null      object
#  10  reason      4 non-null      object
#  11  guardian    4 non-null      object
#  12  traveltime  4 non-null      int64
#  13  studytime   4 non-null      int64
#  14  failures    4 non-null      int64
#  15  schoolsup   4 non-null      object
#  16  famsup      4 non-null      object
#  17  paid        4 non-null      object
#  18  activities  4 non-null      object
# ...

# %% [markdown]
# Step 3:-Dataset Overview

# %% [markdown]
# ![Screenshot 2026-01-18 135829.png](data:image/png;base64,...)

# %% [markdown]
# Step 4:- Data Types & Summary

# %%
df.describe()
# Out:
#          age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# count   4.00  4.000000  4.000000        4.00       4.00      4.00  4.000000
# mean   16.25  2.500000  2.000000        1.25       2.25      0.75  4.000000
# std     1.50  1.732051  1.414214        0.50       0.50      1.50  0.816497
# min    15.00  1.000000  1.000000        1.00       2.00      0.00  3.000000
# 25%    15.00  1.000000  1.000000        1.00       2.00      0.00  3.750000
# 50%    16.00  2.500000  1.500000        1.00       2.00      0.00  4.000000
# 75%    17.25  4.000000  2.500000        1.25       2.25      0.75  4.250000
# max    18.00  4.000000  4.000000        2.00       3.00      3.00  5.000000
#
#        freetime     goout  Dalc  Walc  health  absences
# count      4.00  4.000000  4.00   4.0     4.0   4.00000
# mean       2.75  2.750000  1.25   1.5     3.5   5.50000
# std        0.50  0.957427  0.50   1.0     1.0   3.41565
# min        2.00  2.000000  1.00   1.0     3.0   2.00000
# ...

# %% [markdown]
# ![Screenshot 2026-01-18 140118.png](data:image/png;base64,...)

# %% [markdown]
# Step 5:- Check Missing Values

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# passed        0
# dtype: int64

# %% [markdown]
# Step 6:- Handle Missing Values (if found)

# %%
# Example strategy: fill numeric columns with mean
for col in df.select_dtypes(include=['float64','int64']).columns:
    df[col].fillna(df[col].mean(), inplace=True)

# Fill categorical values with mode
for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

df.isnull().sum()
# Out:
# /tmp/ipython-input-1648347935.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /tmp/ipython-input-1648347935.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Step 7:- Remove Duplicate Records

# %%
before = df.shape[0]
df.drop_duplicates(inplace=True)
after = df.shape[0]
print('Duplicates removed:', before - after)
# Out:
# Duplicates removed: 0

# %% [markdown]
# Step 8:- Encode Categorical Column

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

categorical_cols = [
    'school', 'sex', 'address', 'famsize', 'Pstatus',
    'Mjob', 'Fjob', 'reason', 'guardian',
    'schoolsup', 'famsup', 'paid', 'activities',
    'nursery', 'higher', 'internet', 'romantic',
    'passed'
]

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

df.sample(min(5, len(df)))
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        0        0        0     4     4     0     2  ...
# 2       0    0   15        0        1        1     1     1     0     0  ...
# 1       0    0   17        0        0        1     1     1     0     0  ...
# 3       0    0   15        0        0        1     4     2     1     1  ...
#
#    internet  romantic  famrel  freetime  goout  Dalc  Walc  health  absences  \
# 0         0         0       4         3      4     1     1       3         6
# 2         1         0       4         3      2     2     3       3        10
# 1         1         0       5         3      3     1     1       3         4
# 3         1         1       3         2      2     1     1       5         2
#
#    passed
# 0       0
# 2       1
# 1       0
# 3       1
#
# [4 rows x 31 columns]

# %% [markdown]
# ![Screenshot 2026-01-18 142535.png](data:image/png;base64,...)

# %% [markdown]
#   Step 9:- Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

numerical_cols = [
    'age', 'Medu', 'Fedu', 'traveltime', 'studytime',
    'failures', 'famrel', 'freetime', 'goout',
    'Dalc', 'Walc', 'health', 'absences'
]

df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
df.sample(min(5, len(df)))
# Out:
#    school  sex       age  address   famsize   Pstatus  Medu      Fedu  \
# 1     0.0  0.0  0.577350      0.0 -0.577350  0.577350  -1.0 -0.816497
# 2     0.0  0.0 -0.962250      0.0  1.732051  0.577350  -1.0 -0.816497
# 3     0.0  0.0 -0.962250      0.0 -0.577350  0.577350   1.0  0.000000
# 0     0.0  0.0  1.347151      0.0 -0.577350 -1.732051   1.0  1.632993
#
#        Mjob      Fjob  ...  internet  romantic    famrel  freetime     goout  \
# 1 -0.577350 -0.904534  ...  0.577350 -0.577350  1.414214  0.577350  0.301511
# 2 -0.577350 -0.904534  ...  0.577350 -0.577350  0.000000  0.577350 -0.904534
# 3  1.732051  0.301511  ...  0.577350  1.732051 -1.414214 -1.732051 -0.904534
# 0 -0.577350  1.507557  ... -1.732051 -0.577350  0.000000  0.577350  1.507557
#
#        Dalc      Walc    health  absences  passed
# 1 -0.577350 -0.577350 -0.577350 -0.507093    -1.0
# 2  1.732051  1.732051 -0.577350  1.521278     1.0
# 3 -0.577350 -0.577350  1.732051 -1.183216     1.0
# ...

# %% [markdown]
# ![Screenshot 2026-01-18 144206.png](data:image/png;base64,...)

# %%
df.to_csv("cleaned_data.csv", index=False)
print("Cleaned data file saved")
# Out:
# Cleaned data file saved

# %% [markdown]
# #Conclusion:-
# The code loads the Iris dataset and looks at its basic details.
# It checks and handles missing values and removes duplicate rows.
# This helps clean the data and make it more reliable.
# Then, the numerical values are scaled to the same range.
